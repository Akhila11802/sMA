# %%
import pandas as pd

# %%
# !pip install snscrape

# %%
import snscrape.modules.twitter as sntwitter

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
import string
import re
import textblob
from textblob import TextBlob

from wordcloud import WordCloud, STOPWORDS

from wordcloud import ImageColorGenerator

import warnings
# %matplotlib inline

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 5000 --since 2023-01-31 twitter-search 'Budget 2023 until:2023-02-03' > text-query-tweets.json")
# Out:
# 256

# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
tweets_df = pd.read_json('text-query-tweets.json', lines=True)

# %%
df = pd.read_csv("Animal_Movie_Comments.csv")

# %%
df.head(5)
# Out:
#    id               author                                        description  \
# 0   1       @ashiqraja1740                              Kish ye movie chahiye
# 1   2  @PradeepKumar-xc6my  Sandeep Reddy arrived and her to rule Indian c...
# 2   3     @user-ge7bu8uy6i                                Movie kab Aayega ❤❤
# 3   4      @imsamiurrahman  But you can't deny the fact that the guy who e...
# 4   5     @bajrangsahu8738                                       Experience 😢
#
#                          guid   to  likecount  \
# 0  UgyXo5f9jktFLc1WjPd4AaABAg  NaN          1
# 1  UgzMqrAugYCBe743oz14AaABAg  NaN          0
# 2  Ugys2YgT2oDb8r99u-B4AaABAg  NaN          1
# 3  UgyD7heFipXsVxDLvN54AaABAg  NaN          0
# 4  UgxGwl_suAewka-TfVp4AaABAg  NaN          0
#
#                                                 link              pubdate  \
# 0  https://www.youtube.com/watch?v=Dydmpfo68DA&lc...  2024-03-16 23:24:39
# ...

# %%
print(df.shape)
# Out:
# (2500, 11)

# %%
df.info()
df.pubdate.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2500 non-null   int64
#  1   author            2500 non-null   object
#  2   description       2500 non-null   object
#  3   guid              2500 non-null   object
#  4   to                327 non-null    object
#  5   likecount         2500 non-null   int64
#  6   link              2500 non-null   object
#  7   pubdate           2500 non-null   object
#  8   replycount        2500 non-null   int64
#  9   title             2500 non-null   object
#  10  authorChannelUrl  2500 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 215.0+ KB
# 2023-12-03 14:37:32    2
# 2023-12-03 11:56:23    2
# 2023-12-15 11:11:46    2
# 2023-12-03 11:57:55    1
# 2023-12-03 11:54:52    1
#                       ..
# 2023-12-10 04:26:46    1
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Heat Map for missing values
plt.figure(figsize=(17, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.xlabel("Column_Name", size=14, weight="bold")
plt.title("Places of missing values in column",fontweight="bold",size=17)
plt.show()

# %%
import plotly.graph_objects as go
Top_Title_Of_tweet= df['title'].value_counts().head(10)

# %%
print (Top_Title_Of_tweet)
# Out:
# Vibes from this Teaser🔥 Another Blockbuster From Bollywood 💥    7
# Hi                                                              6
# Hello dosto kya aap ko animal full movie chahiye                6
# ❤                                                               6
# 😂😂                                                              6
# 😂😂😂                                                             6
# Best movie                                                      5
# ❤❤                                                              5
# Nice movie                                                      4
# 🔥🔥🔥                                                             3
# Name: title, dtype: int64

# %%
import nltk

# %%
stop=nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df.head())
# Out:
#    id               author                                        description  \
# 0   1       @ashiqraja1740                              Kish ye movie chahiye
# 1   2  @PradeepKumar-xc6my  Sandeep Reddy arrived and her to rule Indian c...
# 2   3     @user-ge7bu8uy6i                                Movie kab Aayega ❤❤
# 3   4      @imsamiurrahman  But you can't deny the fact that the guy who e...
# 4   5     @bajrangsahu8738                                       Experience 😢
#
#                          guid   to  likecount  \
# 0  UgyXo5f9jktFLc1WjPd4AaABAg  NaN          1
# 1  UgzMqrAugYCBe743oz14AaABAg  NaN          0
# 2  Ugys2YgT2oDb8r99u-B4AaABAg  NaN          1
# 3  UgyD7heFipXsVxDLvN54AaABAg  NaN          0
# 4  UgxGwl_suAewka-TfVp4AaABAg  NaN          0
#
#                                                 link              pubdate  \
# 0  https://www.youtube.com/watch?v=Dydmpfo68DA&lc...  2024-03-16 23:24:39
# ...

# %%
df_cleaned = df.drop(['guid', 'to', 'link', 'replycount', 'authorChannelUrl'], axis=1)

# Visualization
print(df_cleaned.head())
# Out:
#    id               author                                        description  \
# 0   1       @ashiqraja1740                              Kish ye movie chahiye
# 1   2  @PradeepKumar-xc6my  Sandeep Reddy arrived and her to rule Indian c...
# 2   3     @user-ge7bu8uy6i                                Movie kab Aayega ❤❤
# 3   4      @imsamiurrahman  But you can't deny the fact that the guy who e...
# 4   5     @bajrangsahu8738                                       Experience 😢
#
#    likecount              pubdate  \
# 0          1  2024-03-16 23:24:39
# 1          0  2024-03-16 11:50:17
# 2          1  2024-03-15 15:36:57
# 3          0  2024-03-14 15:57:40
# 4          0  2024-03-14 01:25:50
#
#                                                title
# 0                              Kish ye movie chahiye
# 1  Sandeep Reddy arrived and her to rule Indian c...
# 2                                Movie kab Aayega ❤❤
# 3  But you can't deny the fact that the guy who e...
# ...

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Text preprocessing function
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

    # Join tokens back into a single string
    preprocessed_text = ' '.join(lemmatized_tokens)

    return preprocessed_text

# Apply text preprocessing to 'description' and 'title' columns
df_cleaned['description'] = df_cleaned['description'].apply(preprocess_text)
df_cleaned['title'] = df_cleaned['title'].apply(preprocess_text)

# %%
print(df_cleaned.head())
# Out:
#    id               author                                        description  \
# 0   1       @ashiqraja1740                              kish ye movie chahiye
# 1   2  @PradeepKumar-xc6my           sandeep reddy arrived rule indian cinema
# 2   3     @user-ge7bu8uy6i                                   movie kab aayega
# 3   4      @imsamiurrahman  cant deny fact guy edited teaser deserves rais...
# 4   5     @bajrangsahu8738                                         experience
#
#    likecount              pubdate  \
# 0          1  2024-03-16 23:24:39
# 1          0  2024-03-16 11:50:17
# 2          1  2024-03-15 15:36:57
# 3          0  2024-03-14 15:57:40
# 4          0  2024-03-14 01:25:50
#
#                                                title
# 0                              kish ye movie chahiye
# 1           sandeep reddy arrived rule indian cinema
# 2                                   movie kab aayega
# 3  cant deny fact guy edited teaser deserves rais...
# ...

# %%
# Visualize 'description' column before and after preprocessing
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['description'].str.len(), bins=20, kde=True, color='skyblue')
plt.title('Before Text Preprocessing: Description Length Distribution')
plt.xlabel('Description Length')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df_cleaned['description'].str.len(), bins=20, kde=True, color='salmon')
plt.title('After Text Preprocessing: Description Length Distribution')
plt.xlabel('Description Length')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Visualize 'title' column before and after preprocessing
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['title'].str.len(), bins=20, kde=True, color='skyblue')
plt.title('Before Text Preprocessing: Title Length Distribution')
plt.xlabel('Title Length')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df_cleaned['title'].str.len(), bins=20, kde=True, color='salmon')
plt.title('After Text Preprocessing: Title Length Distribution')
plt.xlabel('Title Length')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df_cleaned['description'] = df['description'].str.replace(r'[^\w\s]', '')
df_cleaned['title'] = df['title'].str.replace(r'[^\w\s]', '')
df_cleaned['author'] = df['author'].str.replace(r'[^\w\s]', '')
# Out:
# <ipython-input-48-0b574c84997e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cleaned['description'] = df['description'].str.replace(r'[^\w\s]', '')
# <ipython-input-48-0b574c84997e>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cleaned['title'] = df['title'].str.replace(r'[^\w\s]', '')
# <ipython-input-48-0b574c84997e>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cleaned['author'] = df['author'].str.replace(r'[^\w\s]', '')

# %%
print(df_cleaned.head())
# Out:
#    id             author                                        description  \
# 0   1      ashiqraja1740                              Kish ye movie chahiye
# 1   2  PradeepKumarxc6my  Sandeep Reddy arrived and her to rule Indian c...
# 2   3     userge7bu8uy6i                                  Movie kab Aayega
# 3   4     imsamiurrahman  But you cant deny the fact that the guy who ed...
# 4   5    bajrangsahu8738                                        Experience
#
#    likecount              pubdate  \
# 0          1  2024-03-16 23:24:39
# 1          0  2024-03-16 11:50:17
# 2          1  2024-03-15 15:36:57
# 3          0  2024-03-14 15:57:40
# 4          0  2024-03-14 01:25:50
#
#                                                title
# 0                              Kish ye movie chahiye
# 1  Sandeep Reddy arrived and her to rule Indian c...
# 2                                  Movie kab Aayega
# 3  But you cant deny the fact that the guy who ed...
# ...

# %%
null_values = df_cleaned.isnull().sum()

print("Null Values in Each Column:")
print(null_values)
# Out:
# Null Values in Each Column:
# id             0
# author         0
# description    0
# likecount      0
# pubdate        0
# title          0
# dtype: int64

# %%
df_cleaned['pubdate'] = pd.to_datetime(df_cleaned['pubdate'])

# Convert 'description' and 'title' columns to lowercase
df_cleaned['description'] = df_cleaned['description'].str.lower()
df_cleaned['title'] = df_cleaned['title'].str.lower()

# Remove leading and trailing whitespaces from 'description' and 'title' columns
df_cleaned['description'] = df_cleaned['description'].str.strip()
df_cleaned['title'] = df_cleaned['title'].str.strip()

# Display the preprocessed DataFrame
print("\nPreprocessed Data:")
print(df_cleaned.head())
# Out:
# Preprocessed Data:
#    id             author                                        description  \
# 0   1      ashiqraja1740                              kish ye movie chahiye
# 1   2  PradeepKumarxc6my  sandeep reddy arrived and her to rule indian c...
# 2   3     userge7bu8uy6i                                   movie kab aayega
# 3   4     imsamiurrahman  but you cant deny the fact that the guy who ed...
# 4   5    bajrangsahu8738                                         experience
#
#    likecount             pubdate  \
# 0          1 2024-03-16 23:24:39
# 1          0 2024-03-16 11:50:17
# 2          1 2024-03-15 15:36:57
# 3          0 2024-03-14 15:57:40
# 4          0 2024-03-14 01:25:50
#
#                                                title
# 0                              kish ye movie chahiye
# 1  sandeep reddy arrived and her to rule indian c...
# 2                                   movie kab aayega
# 3  but you cant deny the fact that the guy who ed...
# ...

# %%
# Remove remaining punctuation
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# %%
# Remove numerical values
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: re.sub(r'\d+', '', x))
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: re.sub(r'\d+', '', x))

# %%
# Tokenization
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: word_tokenize(x))
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: word_tokenize(x))

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: [word for word in x if word.lower() not in stop_words])
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %%
# Join tokens back into strings
df_cleaned['description'] = df_cleaned['description'].apply(lambda x: ' '.join(x))
df_cleaned['title'] = df_cleaned['title'].apply(lambda x: ' '.join(x))

# %%
# Display the preprocessed DataFrame
print("\nFully Preprocessed Data:")
print(df_cleaned.head())
# Out:
# Fully Preprocessed Data:
#    id             author                                        description  \
# 0   1      ashiqraja1740                              kish ye movie chahiye
# 1   2  PradeepKumarxc6my           sandeep reddy arrived rule indian cinema
# 2   3     userge7bu8uy6i                                   movie kab aayega
# 3   4     imsamiurrahman  cant deny fact guy edited teaser deserves rais...
# 4   5    bajrangsahu8738                                         experience
#
#    likecount             pubdate  \
# 0          1 2024-03-16 23:24:39
# 1          0 2024-03-16 11:50:17
# 2          1 2024-03-15 15:36:57
# 3          0 2024-03-14 15:57:40
# 4          0 2024-03-14 01:25:50
#
#                                                title
# 0                              kish ye movie chahiye
# 1           sandeep reddy arrived rule indian cinema
# 2                                   movie kab aayega
# 3  cant deny fact guy edited teaser deserves rais...
# ...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis on 'description' and 'title' columns
df_cleaned['description_sentiment'] = df_cleaned['description'].apply(lambda x: sid.polarity_scores(x)['compound'])
df_cleaned['title_sentiment'] = df_cleaned['title'].apply(lambda x: sid.polarity_scores(x)['compound'])

# Display the DataFrame with sentiment scores
print(df_cleaned[['description', 'description_sentiment', 'title', 'title_sentiment']])
# Out:
#                                             description  \
# 0                                 kish ye movie chahiye
# 1              sandeep reddy arrived rule indian cinema
# 2                                      movie kab aayega
# 3     cant deny fact guy edited teaser deserves rais...
# 4                                            experience
# ...                                                 ...
# 2495                                  whare bipin karki
# 2496                                     teaser trailer
# 2497                                     tiger superhit
# 2498                                     best hindu boy
# 2499                     bollywood best movie funtastic
#
#       description_sentiment  \
# 0                    0.0000
# 1                    0.0000
# 2                    0.0000
# 3                   -0.4382
# 4                    0.0000
# ...                     ...
# 2495                 0.0000
# 2496                -0.2500
# ...

# %%
def get_sentiment_label(score):
    if score > 0:
        return "positive"
    elif score < 0:
        return "negative"
    else:
        return "neutral"

# Apply the function to the sentiment scores
df_cleaned['description_sentiment_label'] = df_cleaned['description_sentiment'].apply(get_sentiment_label)
df_cleaned['title_sentiment_label'] = df_cleaned['title_sentiment'].apply(get_sentiment_label)

# Display the DataFrame with sentiment labels
print(df_cleaned[['description', 'description_sentiment_label', 'title', 'title_sentiment_label']])
# Out:
#                                             description  \
# 0                                 kish ye movie chahiye
# 1              sandeep reddy arrived rule indian cinema
# 2                                      movie kab aayega
# 3     cant deny fact guy edited teaser deserves rais...
# 4                                            experience
# ...                                                 ...
# 2495                                  whare bipin karki
# 2496                                     teaser trailer
# 2497                                     tiger superhit
# 2498                                     best hindu boy
# 2499                     bollywood best movie funtastic
#
#      description_sentiment_label  \
# 0                        neutral
# 1                        neutral
# 2                        neutral
# 3                       negative
# 4                        neutral
# ...                          ...
# 2495                     neutral
# ...

# %%
# Drop 'title', 'title_sentiment', and 'likecount' columns
df_cleaned.drop(['title', 'title_sentiment', 'title_sentiment_label'], axis=1, inplace=True)

# Display the DataFrame with dropped columns
print(df_cleaned)
# Out:
#         id              author  \
# 0        1       ashiqraja1740
# 1        2   PradeepKumarxc6my
# 2        3      userge7bu8uy6i
# 3        4      imsamiurrahman
# 4        5     bajrangsahu8738
# ...    ...                 ...
# 2495  2496         seemoon7683
# 2496  2497     amanvermaji6619
# 2497  2498      userjy3cg9xw1s
# 2498  2499  digantguttedar4059
# 2499  2500    avdheshyadav5380
#
#                                             description  likecount  \
# 0                                 kish ye movie chahiye          1
# 1              sandeep reddy arrived rule indian cinema          0
# 2                                      movie kab aayega          1
# 3     cant deny fact guy edited teaser deserves rais...          0
# 4                                            experience          0
# ...                                                 ...        ...
# 2495                                  whare bipin karki          0
# ...

# %%
# Drop 'author', 'pubdate', 'id', 'description', and 'sentiment' columns
df_cleaned.drop(['author', 'pubdate', 'description_sentiment'], axis=1, inplace=True)

# Display the DataFrame with dropped columns
print(df_cleaned)
# Out:
#         id                                        description  likecount  \
# 0        1                              kish ye movie chahiye          1
# 1        2           sandeep reddy arrived rule indian cinema          0
# 2        3                                   movie kab aayega          1
# 3        4  cant deny fact guy edited teaser deserves rais...          0
# 4        5                                         experience          0
# ...    ...                                                ...        ...
# 2495  2496                                  whare bipin karki          0
# 2496  2497                                     teaser trailer          0
# 2497  2498                                     tiger superhit          0
# 2498  2499                                     best hindu boy          0
# 2499  2500                     bollywood best movie funtastic          0
#
#      description_sentiment_label
# 0                        neutral
# ...

# %%
df_cleaned.drop(['id'], axis=1, inplace=True)

# Display the DataFrame with dropped columns
print(df_cleaned)
# Out:
#                                             description  likecount  \
# 0                                 kish ye movie chahiye          1
# 1              sandeep reddy arrived rule indian cinema          0
# 2                                      movie kab aayega          1
# 3     cant deny fact guy edited teaser deserves rais...          0
# 4                                            experience          0
# ...                                                 ...        ...
# 2495                                  whare bipin karki          0
# 2496                                     teaser trailer          0
# 2497                                     tiger superhit          0
# 2498                                     best hindu boy          0
# 2499                     bollywood best movie funtastic          0
#
#      description_sentiment_label
# 0                        neutral
# 1                        neutral
# 2                        neutral
# ...

# %%
pip install textblob wordcloud

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Function to perform sentiment analysis using TextBlob
def analyze_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity < 0:
        return 'negative'
    else:
        return 'neutral'

# Apply sentiment analysis to the 'description' column
df_cleaned['description_sentiment'] = df_cleaned['description'].apply(analyze_sentiment)

# %%
# Count the number of positive, negative, and neutral sentiments
sentiment_counts = df_cleaned['description_sentiment'].value_counts()

# Plot sentiment distribution
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Join all description texts into a single string
text = ' '.join(df_cleaned['description'])

# Generate WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the WordCloud
plt.figure(figsize=(14, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Descriptions')
plt.axis('off')
plt.show()

# %%
# Word Frequency
from collections import Counter

words = ' '.join(df['description']).split()
word_freq = Counter(words)
word_freq_df = pd.DataFrame(list(word_freq.items()), columns=['Word', 'Frequency'])
word_freq_df = word_freq_df.sort_values(by='Frequency', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(word_freq_df['Word'], word_freq_df['Frequency'], color='skyblue')
plt.title('Top 10 Most Frequent Words')
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
